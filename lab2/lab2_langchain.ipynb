# %%
# !pip install -qU langchain langchain-core langchain-openai openai

# %%
import os

os.environ["OPENAI_API_KEY"] = "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"
os.environ["OPENAI_API_BASE"] = "https://openrouter.ai/api/v1"

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate

# OpenRouter Model
llm = ChatOpenAI(
    model="mistralai/mistral-7b-instruct",
    temperature=0.5,
    base_url="https://openrouter.ai/api/v1"
)

# Prompt
prompt = ChatPromptTemplate.from_template(
    "Explain {topic} in simple terms with one real-world example."
)

# Chain (LCEL style)
chain = prompt | llm

# Run
response = chain.invoke({"topic": "Machine Learning"})
print(response.content)
# Out:
#  Machine Learning (ML) is a subset of Artificial Intelligence (AI) that allows computer systems to automatically learn and improve from experience without being explicitly programmed. In simple terms, it's like teaching a computer to learn and make decisions based on data.
#
# A real-world example of machine learning is email spam filtering. When you receive an email, your email service provider uses machine learning to identify whether the email is spam or not. The system is trained on a large dataset of spam and non-spam emails. It learns to recognize patterns and characteristics of spam emails, such as certain words, phrases, or links, and uses this knowledge to classify new emails. Over time, as more emails are processed, the system gets better at making accurate decisions, improving the effectiveness of the spam filter.
#
# ...
